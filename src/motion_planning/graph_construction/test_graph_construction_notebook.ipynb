# %% [markdown]
# ### Testing graph construction module on different environments

# %% [markdown]
# #### imports

# %%
from pathlib import Path
import sys
# add <project>/src to sys.path
sys.path.insert(0, str(Path.cwd().resolve().parents[1]))
# now imports work
from motion_planning.graph_construction.main_graph_construction import GraphConstruction

from motion_planning.utils.launch_carla import *  
from motion_planning.graph_construction.route_loading import *
from motion_planning.visualizations.graph_visualization import GRAPH_VISUALIZATION
from motion_planning.graph_construction.graph_assets import GRAPH_FILE_HANDLER
from motion_planning.utils.paths import GRAPH_DIR
from pathlib import Path
import time

# %%
for map_id_key, scenario_key in routes_config.keys():
    print(f"+ Map={map_id_key}, << scenario={scenario_key} >>")
# Out:
# + Map=Town01, << scenario=T-Intersection >>
# + Map=Town03, << scenario=Roundabout >>
# + Map=Town05, << scenario=Highway1 >>
# + Map=Town05, << scenario=Highway2 >>
# + Map=Town05, << scenario=Highway3 >>
# + Map=Town05, << scenario=Multiple Intersections >>

# %% [markdown]
# The following code is to do it in a loop to generate the graphs, however, it crashes in the middle.
# So, we will generate it one by one.

# %%
# generate and save graphs for all scenarios in routes_config
# launch_carla_server()

# for map_id_key, scenario_key in routes_config.keys():
#     try:
#         time.sleep(5)  # wait for server to be ready
#         print(f"Processing map={map_id_key}, scenario={scenario_key} ...")
#         gc = GraphConstruction(map_id_key, scenario_key, n_seperated_wps=10, num_paths=10, path_offset=1, scenario=scenario_key)
#         gc.construct_graph_from_carla_route()
#         # build frenet and networkx structures
#         gc.create_frenet_graph()
#         G_all, goal_indices, ref = gc.create_graph_data_structure()
#         # save using existing handler and GRAPH_DIR
#         graph_handler = GRAPH_FILE_HANDLER()
#         save_name = f"{map_id_key}_{scenario_key}"
#         graph_handler.save_graph(graph=G_all, save_dir=GRAPH_DIR, scenario=save_name)
#         print(f"Saved graph: {save_name}")
#         # close_carla_server()
#         time.sleep(5)  # ensure server is closed before next iteration
#     except Exception as e:
#         print(f"Failed for {map_id_key},{scenario_key}: {e}")

# %% [markdown]
# restart the kernel, then run the next code [scenario] [Town01] [T-Intersection]

# %%
from pathlib import Path
import sys
# add <project>/src to sys.path
sys.path.insert(0, str(Path.cwd().resolve().parents[1]))
# now imports work
from motion_planning.graph_construction.main_graph_construction import GraphConstruction

from motion_planning.utils.launch_carla import *  
from motion_planning.graph_construction.route_loading import *
from motion_planning.visualizations.graph_visualization import GRAPH_VISUALIZATION
from motion_planning.graph_construction.graph_assets import GRAPH_FILE_HANDLER
from motion_planning.utils.paths import GRAPH_DIR, ROUTES_DIR
from pathlib import Path
import time

map_id_key = 'Town01'
scenario_key = 'T-Intersection'
launch_carla_server()
time.sleep(5)  # wait for server to be ready
print(f"Processing map={map_id_key}, scenario={scenario_key} ...")
gc = GraphConstruction(map_id_key, scenario_key, n_seperated_wps=10, num_paths=10, path_offset=1, scenario=scenario_key)
gc.construct_graph_from_carla_route()
# build frenet and networkx structures
gc.create_frenet_graph()
G_all, goal_indices, ref = gc.create_graph_data_structure()
# save using existing handler and GRAPH_DIR
GV = GRAPH_VISUALIZATION(gc.V, gc.E, world= gc.get_current_world(), scenario=scenario_key)
GV.visualize_final_graph_matplotlib()

graph_handler = GRAPH_FILE_HANDLER()
save_name = f"{map_id_key}_{scenario_key}"
graph_handler.save_graph(graph=G_all, save_dir=GRAPH_DIR, scenario=save_name)
graph_handler.save_reference_path_csv(path=ref, save_dir=ROUTES_DIR, scenario=save_name)

print(f"Saved graph: {save_name}")
# close_carla_server()
time.sleep(5)  # ensure server is closed before next iteration
# Out:
# Processing map=Town01, scenario=T-Intersection ...
# WARNING: Version mismatch detected: You are trying to connect to a simulator that might be incompatible with this API
# WARNING: Client API version     = 0.9.14
# WARNING: Simulator API version  = 0.9.15
# Location(x=200.000000, y=200.000000, z=0.300000)
# Goal is: Location(x=336.000000, y=276.000000, z=0.300000)
# waypoints:  [200.41983032 199.14892578] [201.41983032 199.14901733]
# ego theta:  9.155273411920462e-05
# waypoints:  [210.41983032 199.1497345 ] [211.41983032 199.14982605]
# ego theta:  9.155273411920462e-05
# waypoints:  [220.41983032 199.15055847] [221.41983032 199.15063477]
# ego theta:  7.629394516447026e-05
# waypoints:  [230.41983032 199.15136719] [231.41983032 199.15144348]
# ego theta:  7.629394516447026e-05
# waypoints:  [240.41983032 199.1521759 ] [241.41983032 199.15226746]
# ego theta:  9.155273411920462e-05
# waypoints:  [250.41983032 199.15298462] [251.41983032 199.15307617]
# ego theta:  9.155273411920462e-05
# waypoints:  [260.41983032 199.15380859] [261.41983032 199.15388489]
# ego theta:  7.629394516447026e-05
# waypoints:  [270.41983032 199.15461731] [271.41983032 199.1546936 ]
# ego theta:  7.629394516447026e-05
# waypoints:  [280.41983032 199.15542603] [281.41983032 199.15551758]
# ego theta:  9.155273411920462e-05
# waypoints:  [290.41983032 199.15625   ] [291.41983032 199.15632629]
# ego theta:  7.629394516447026e-05
# waypoints:  [300.41983032 199.15705872] [301.41983032 199.15713501]
# ego theta:  7.629394516447026e-05
# waypoints:  [310.41983032 199.15786743] [311.41983032 199.15794373]
# ego theta:  7.629394516447026e-05
# waypoints:  [320.41983032 199.15867615] [321.41983032 199.1587677 ]
# ego theta:  9.155273411920462e-05
# waypoints:  [330.09637451 199.42933655] [330.83706665 199.68196106]
# ego theta:  0.3286932601743394
# waypoints:  [334.76364136 204.73231506] [334.77572632 205.59677124]
# ego theta:  1.5568173952123063
# waypoints:  [334.7699585  215.15875244] [334.76934814 216.15875244]
# ego theta:  1.5714066782816054
# waypoints:  [334.76391602 225.15875244] [334.76333618 226.15875244]
# ego theta:  1.5713761607142902
# waypoints:  [334.75787354 235.15875244] [334.7572937  236.15875244]
# ego theta:  1.5713761607142902
# waypoints:  [334.75183105 245.15873718] [334.75125122 246.15873718]
# ego theta:  1.5713761607142902
# waypoints:  [334.74581909 255.15873718] [334.74520874 256.15872192]
# ego theta:  1.5714066875949697
# ego theta:  1.5714066875949697
# V[-1]= [<motion_planning.graph_construction.graph_assets.Node object at 0x7e3944363130>, <motion_planning.graph_construction.graph_assets.Node object at 0x7e3944363160>, <motion_planning.graph_construction.graph_assets.Node object at 0x7e3944363190>, <motion_planning.graph_construction.graph_assets.Node object at 0x7e39443631c0>, <motion_planning.graph_construction.graph_assets.Node object at 0x7e39443631f0>, <motion_planning.graph_construction.graph_assets.Node object at 0x7e3944363220>, <motion_planning.graph_construction.graph_assets.Node object at 0x7e3944363250>]
# last layer:  [334.7337341308594, 275.1587219238281, 1.5714066875949697, None]
# layer  0  has  1  nodes
# layer  1  has  7  nodes
# layer  2  has  7  nodes
# layer  3  has  7  nodes
# layer  4  has  7  nodes
# layer  5  has  7  nodes
# layer  6  has  7  nodes
# layer  7  has  7  nodes
# layer  8  has  7  nodes
# layer  9  has  7  nodes
# layer  10  has  7  nodes
# layer  11  has  7  nodes
# layer  12  has  7  nodes
# layer  13  has  7  nodes
# layer  14  has  7  nodes
# layer  15  has  7  nodes
# layer  16  has  7  nodes
# layer  17  has  7  nodes
# layer  18  has  7  nodes
# layer  19  has  7  nodes
# layer  20  has  7  nodes
# layer  21  has  1  nodes
# planning done!:  0
# [True, True, True, True, True, True, True]
# planning done!:  1
# [True, True, True, True, True, True, True]
# planning done!:  1
# [True, True, True, True, True, True, True]
# planning done!:  1
# [True, True, True, True, True, True, True]
# planning done!:  1
# [True, True, True, True, True, True, True]
# planning done!:  1
# [True, True, True, True, True, True, True]
# planning done!:  1
# [True, True, True, True, True, True, True]
# planning done!:  1
# [True, True, True, True, True, True, True]
# planning done!:  2
# [True, True, True, True, True, True, True]
# planning done!:  2
# [True, True, True, True, True, True, True]
# planning done!:  2
# [True, True, True, True, True, True, True]
# planning done!:  2
# [True, True, True, True, True, True, True]
# /home/abdulrahman/competitive-online-algorithms-motion-planning/src/motion_planning/graph_construction/path_optimization.py:87: RuntimeWarning: Method L-BFGS-B cannot handle constraints.
#   res = scipy.optimize.minimize(self.objective, p0, method='L-BFGS-B', jac=self.objective_grad, constraints=bounds)
# planning done!:  2
# [True, True, True, True, True, True, True]
# planning done!:  2
# [True, True, True, True, True, True, True]
# planning done!:  2
# [True, True, True, True, True, True, True]
# planning done!:  3
# [True, True, True, True, True, True, True]
# planning done!:  3
# [True, True, True, True, True, True, True]
# planning done!:  3
# [True, True, True, True, True, True, True]
# planning done!:  3
# [True, True, True, True, True, True, True]
# planning done!:  3
# [True, True, True, True, True, True, True]
# planning done!:  3
# [True, True, True, True, True, True, True]
# planning done!:  3
# [True, True, True, True, True, True, True]
# planning done!:  4
# [True, True, True, True, True, True, True]
# planning done!:  4
# [True, True, True, True, True, True, True]
# planning done!:  4
# [True, True, True, True, True, True, True]
# planning done!:  4
# [True, True, True, True, True, True, True]
# planning done!:  4
# [True, True, True, True, True, True, True]
# planning done!:  4
# [True, True, True, True, True, True, True]
# planning done!:  4
# [True, True, True, True, True, True, True]
# planning done!:  5
# [True, True, True, True, True, True, True]
# planning done!:  5
# [True, True, True, True, True, True, True]
# planning done!:  5
# [True, True, True, True, True, True, True]
# planning done!:  5
# [True, True, True, True, True, True, True]
# planning done!:  5
# [True, True, True, True, True, True, True]
# planning done!:  5
# [True, True, True, True, True, True, True]
# planning done!:  5
# [True, True, True, True, True, True, True]
# planning done!:  6
# [True, True, True, True, True, True, True]
# planning done!:  6
# [True, True, True, True, True, True, True]
# planning done!:  6
# [True, True, True, True, True, True, True]
# planning done!:  6
# [True, True, True, True, True, True, True]
# planning done!:  6
# [True, True, True, True, True, True, True]
# planning done!:  6
# [True, True, True, True, True, True, True]
# planning done!:  6
# [True, True, True, True, True, True, True]
# planning done!:  7
# [True, True, True, True, True, True, True]
# planning done!:  7
# [True, True, True, True, True, True, True]
# planning done!:  7
# [True, True, True, True, True, True, True]
# planning done!:  7
# [True, True, True, True, True, True, True]
# planning done!:  7
# [True, True, True, True, True, True, True]
# planning done!:  7
# [True, True, True, True, True, True, True]
# planning done!:  7
# [True, True, True, True, True, True, True]
# planning done!:  8
# [True, True, True, True, True, True, True]
# planning done!:  8
# [True, True, True, True, True, True, True]
# planning done!:  8
# [True, True, True, True, True, True, True]
# planning done!:  8
# [True, True, True, True, True, True, True]
# planning done!:  8
# [True, True, True, True, True, True, True]
# planning done!:  8
# [True, True, True, True, True, True, True]
# planning done!:  8
# [True, True, True, True, True, True, True]
# planning done!:  9
# [True, True, True, True, True, True, True]
# planning done!:  9
# [True, True, True, True, True, True, True]
# planning done!:  9
# [True, True, True, True, True, True, True]
# planning done!:  9
# [True, True, True, True, True, True, True]
# planning done!:  9
# [True, True, True, True, True, True, True]
# planning done!:  9
# [True, True, True, True, True, True, True]
# planning done!:  9
# [True, True, True, True, True, True, True]
# planning done!:  10
# [True, True, True, True, True, True, True]
# planning done!:  10
# [True, True, True, True, True, True, True]
# planning done!:  10
# [True, True, True, True, True, True, True]
# planning done!:  10
# [True, True, True, True, True, True, True]
# planning done!:  10
# [True, True, True, True, True, True, True]
# planning done!:  10
# [True, True, True, True, True, True, True]
# planning done!:  10
# [True, True, True, True, True, True, True]
# planning done!:  11
# [True, True, True, True, True, True, True]
# planning done!:  11
# [True, True, True, True, True, True, True]
# planning done!:  11
# [True, True, True, True, True, True, True]
# planning done!:  11
# [True, True, True, True, True, True, True]
# planning done!:  11
# [True, True, True, True, True, True, True]
# planning done!:  11
# [True, True, True, True, True, True, True]
# planning done!:  11
# [True, True, True, True, True, True, True]
# planning done!:  12
# [True, True, True, True, True, True, True]
# planning done!:  12
# [True, True, True, True, True, True, True]
# planning done!:  12
# [True, True, True, True, True, True, True]
# planning done!:  12
# [True, True, True, True, True, True, True]
# planning done!:  12
# [True, True, True, True, True, True, True]
# planning done!:  12
# [True, True, True, True, True, True, True]
# planning done!:  12
# [True, True, True, True, True, True, True]
# planning done!:  13
# [True, True, True, True, True, True, True]
# planning done!:  13
# [True, True, True, True, True, True, True]
# planning done!:  13
# [True, True, True, True, True, True, True]
# planning done!:  13
# [True, True, True, True, True, True, True]
# planning done!:  13
# [True, True, True, True, True, True, True]
# planning done!:  13
# [True, True, True, True, True, True, True]
# planning done!:  13
# [True, True, True, True, True, True, True]
# planning done!:  14
# [True, True, True, True, True, True, True]
# planning done!:  14
# [True, True, True, True, True, True, True]
# planning done!:  14
# [True, True, True, True, True, True, True]
# planning done!:  14
# [True, True, True, True, True, True, True]
# planning done!:  14
# [True, True, True, True, True, True, True]
# planning done!:  14
# [True, True, True, True, True, True, True]
# planning done!:  14
# [True, True, True, True, True, True, True]
# planning done!:  15
# [True, True, True, True, True, True, True]
# planning done!:  15
# [True, True, True, True, True, True, True]
# planning done!:  15
# [True, True, True, True, True, True, True]
# planning done!:  15
# [True, True, True, True, True, True, True]
# planning done!:  15
# [True, True, True, True, True, True, True]
# planning done!:  15
# [True, True, True, True, True, True, True]
# planning done!:  15
# [True, True, True, True, True, True, True]
# planning done!:  16
# [True, True, True, True, True, True, True]
# planning done!:  16
# [True, True, True, True, True, True, True]
# planning done!:  16
# [True, True, True, True, True, True, True]
# planning done!:  16
# [True, True, True, True, True, True, True]
# planning done!:  16
# [True, True, True, True, True, True, True]
# planning done!:  16
# [True, True, True, True, True, True, True]
# planning done!:  16
# [True, True, True, True, True, True, True]
# planning done!:  17
# [True, True, True, True, True, True, True]
# planning done!:  17
# [True, True, True, True, True, True, True]
# planning done!:  17
# [True, True, True, True, True, True, True]
# planning done!:  17
# [True, True, True, True, True, True, True]
# planning done!:  17
# [True, True, True, True, True, True, True]
# planning done!:  17
# [True, True, True, True, True, True, True]
# planning done!:  17
# [True, True, True, True, True, True, True]
# planning done!:  18
# [True, True, True, True, True, True, True]
# planning done!:  18
# [True, True, True, True, True, True, True]
# planning done!:  18
# [True, True, True, True, True, True, True]
# planning done!:  18
# [True, True, True, True, True, True, True]
# planning done!:  18
# [True, True, True, True, True, True, True]
# planning done!:  18
# [True, True, True, True, True, True, True]
# planning done!:  18
# [True, True, True, True, True, True, True]
# planning done!:  19
# [True, True, True, True, True, True, True]
# planning done!:  19
# [True, True, True, True, True, True, True]
# planning done!:  19
# [True, True, True, True, True, True, True]
# planning done!:  19
# [True, True, True, True, True, True, True]
# planning done!:  19
# [True, True, True, True, True, True, True]
# planning done!:  19
# [True, True, True, True, True, True, True]
# planning done!:  19
# [True, True, True, True, True, True, True]
# planning done!:  20
# [True]
# planning done!:  20
# [True]
# planning done!:  20
# [True]
# planning done!:  20
# [True]
# planning done!:  20
# [True]
# planning done!:  20
# [True]
# planning done!:  20
# [True]
# Saved graph: Town01_T-Intersection

# %% [markdown]
# restart kernel, then run the next [scenario] [Town03] [Roundabout]

# %%
from pathlib import Path
import sys
# add <project>/src to sys.path
sys.path.insert(0, str(Path.cwd().resolve().parents[1]))
# now imports work
from motion_planning.graph_construction.main_graph_construction import GraphConstruction

from motion_planning.utils.launch_carla import *  
from motion_planning.graph_construction.route_loading import *
from motion_planning.visualizations.graph_visualization import GRAPH_VISUALIZATION
from motion_planning.graph_construction.graph_assets import GRAPH_FILE_HANDLER
from motion_planning.utils.paths import GRAPH_DIR, ROUTES_DIR
from pathlib import Path
import time


map_id_key = 'Town03'
scenario_key = 'Roundabout'

launch_carla_server()
time.sleep(5)  # wait for server to be ready
print(f"Processing map={map_id_key}, scenario={scenario_key} ...")
gc = GraphConstruction(map_id_key, scenario_key, n_seperated_wps=10, num_paths=10, path_offset=1, scenario=scenario_key)
gc.construct_graph_from_carla_route()
# build frenet and networkx structures
gc.create_frenet_graph()
G_all, goal_indices, ref = gc.create_graph_data_structure()
# save using existing handler and GRAPH_DIR
GV = GRAPH_VISUALIZATION(gc.V, gc.E, world= gc.get_current_world(), scenario=scenario_key)
GV.visualize_final_graph_matplotlib()

graph_handler = GRAPH_FILE_HANDLER()
save_name = f"{map_id_key}_{scenario_key}"
graph_handler.save_graph(graph=G_all, save_dir=GRAPH_DIR, scenario=save_name)
graph_handler.save_reference_path_csv(path=ref, save_dir=ROUTES_DIR, scenario=save_name)

print(f"Saved graph: {save_name}")
# close_carla_server()
time.sleep(5)  # ensure server is closed before next iteration
# Out:
# Processing map=Town03, scenario=Roundabout ...
# Scenario:  Roundabout
# WARNING: Version mismatch detected: You are trying to connect to a simulator that might be incompatible with this API
# WARNING: Client API version     = 0.9.14
# WARNING: Simulator API version  = 0.9.15
# Location(x=5.000000, y=100.000000, z=0.275307)
# Goal is: Location(x=100.000000, y=8.000000, z=0.275307)
# waypoints:  [  5.29142857 100.25244141] [ 5.27877378 98.25247955]
# ego theta:  -1.5771237537097018
# waypoints:  [ 5.22815466 90.2526474 ] [ 5.21549988 88.25267792]
# ego theta:  -1.5771237295727596
# waypoints:  [ 5.16488075 80.25284576] [ 5.15222645 78.25287628]
# ego theta:  -1.5771234911600875
# waypoints:  [ 5.10160732 70.25304413] [ 5.08895254 68.25308228]
# ego theta:  -1.5771237537097018
# waypoints:  [ 5.03833342 60.25324631] [ 5.02567863 58.25328445]
# ego theta:  -1.5771237537097018
# waypoints:  [ 4.97505951 50.25344467] [ 4.96240473 48.25348663]
# ego theta:  -1.577123765778242
# waypoints:  [ 4.95686865 39.62411118] [ 5.09187794 37.71902466]
# ego theta:  -1.5000468098461777
# waypoints:  [ 6.60466099 30.22163582] [ 7.16983128 28.34048462]
# ego theta:  -1.2789372661056342
# waypoints:  [10.63713646 21.89803886] [11.85398674 20.51956558]
# ego theta:  -0.8475925487581208
# waypoints:  [18.18149948 14.29440689] [19.43780518 12.50285339]
# ego theta:  -0.9592398596146033
# waypoints:  [24.6404438   8.04937553] [26.2810421   7.48075819]
# ego theta:  -0.33363502856763894
# waypoints:  [36.40196228  7.08893681] [38.39491272  7.10292578]
# ego theta:  0.007019111813634984
# waypoints:  [48.32537079  7.24257183] [50.32514572  7.27244377]
# ego theta:  0.014936540412564385
# waypoints:  [58.32425308  7.39193106] [60.32403183  7.421803  ]
# ego theta:  0.014936511924460013
# waypoints:  [68.453125    7.54323196] [70.45290375  7.5731039 ]
# ego theta:  0.014936511924460013
# ego theta:  0.014936511924460013
# V[-1]= [<motion_planning.graph_construction.graph_assets.Node object at 0x7916b0247a00>, <motion_planning.graph_construction.graph_assets.Node object at 0x7916b0247a30>, <motion_planning.graph_construction.graph_assets.Node object at 0x7916b0247a60>, <motion_planning.graph_construction.graph_assets.Node object at 0x7916b0247a90>, <motion_planning.graph_construction.graph_assets.Node object at 0x7916b0247ac0>, <motion_planning.graph_construction.graph_assets.Node object at 0x7916b0247af0>]
# last layer:  [97.45988464355469, 7.976522922515869, 0.014936511924460013, None]
# layer  0  has  1  nodes
# layer  1  has  6  nodes
# layer  2  has  6  nodes
# layer  3  has  6  nodes
# layer  4  has  6  nodes
# layer  5  has  6  nodes
# layer  6  has  6  nodes
# layer  7  has  6  nodes
# layer  8  has  7  nodes
# layer  9  has  6  nodes
# layer  10  has  7  nodes
# layer  11  has  6  nodes
# layer  12  has  6  nodes
# layer  13  has  6  nodes
# layer  14  has  6  nodes
# layer  15  has  6  nodes
# layer  16  has  1  nodes
# planning done!:  0
# [True, True, True, True, True, True]
# planning done!:  1
# [True, True, True, True, True, True]
# planning done!:  1
# [True, True, True, True, True, True]
# planning done!:  1
# [True, True, True, True, True, True]
# planning done!:  1
# [True, True, True, True, True, True]
# planning done!:  1
# [True, True, True, True, True, True]
# planning done!:  1
# [True, True, True, True, True, True]
# planning done!:  2
# [True, True, True, True, True, True]
# planning done!:  2
# [True, True, True, True, True, True]
# planning done!:  2
# [True, True, True, True, True, True]
# planning done!:  2
# [True, True, True, True, True, True]
# planning done!:  2
# [True, True, True, True, True, True]
# planning done!:  2
# [True, True, True, True, True, True]
# planning done!:  3
# [True, True, True, True, True, True]
# planning done!:  3
# [True, True, True, True, True, True]
# /home/abdulrahman/competitive-online-algorithms-motion-planning/src/motion_planning/graph_construction/path_optimization.py:87: RuntimeWarning: Method L-BFGS-B cannot handle constraints.
#   res = scipy.optimize.minimize(self.objective, p0, method='L-BFGS-B', jac=self.objective_grad, constraints=bounds)
# planning done!:  3
# [True, True, True, True, True, True]
# planning done!:  3
# [True, True, True, True, True, True]
# planning done!:  3
# [True, True, True, True, True, True]
# planning done!:  3
# [True, True, True, True, True, True]
# planning done!:  4
# [True, True, True, True, True, True]
# planning done!:  4
# [True, True, True, True, True, True]
# planning done!:  4
# [True, True, True, True, True, True]
# planning done!:  4
# [True, True, True, True, True, True]
# planning done!:  4
# [True, True, True, True, True, True]
# planning done!:  4
# [True, True, True, True, True, True]
# planning done!:  5
# [True, True, True, True, True, True]
# planning done!:  5
# [True, True, True, True, True, True]
# planning done!:  5
# [True, True, True, True, True, True]
# planning done!:  5
# [True, True, True, True, True, True]
# planning done!:  5
# [True, True, True, True, True, True]
# planning done!:  5
# [True, True, True, True, True, True]
# planning done!:  6
# [True, True, True, True, True, True]
# planning done!:  6
# [True, True, True, True, True, True]
# planning done!:  6
# [True, True, True, True, True, True]
# planning done!:  6
# [True, True, True, True, True, True]
# planning done!:  6
# [True, True, True, True, True, True]
# planning done!:  6
# [True, True, True, True, True, True]
# planning done!:  7
# [True, True, True, True, True, True, True]
# planning done!:  7
# [True, True, True, True, True, True, True]
# planning done!:  7
# [True, True, True, True, True, True, True]
# planning done!:  7
# [True, True, True, True, True, True, True]
# planning done!:  7
# [True, True, True, True, True, True, True]
# planning done!:  7
# [True, True, True, True, True, True, True]
# planning done!:  8
# [True, True, True, True, True, True]
# planning done!:  8
# [True, True, True, True, True, True]
# planning done!:  8
# [True, True, True, True, True, True]
# planning done!:  8
# [True, True, True, True, True, True]
# planning done!:  8
# [True, True, True, True, True, True]
# planning done!:  8
# [True, True, True, True, True, True]
# planning done!:  8
# [True, True, True, True, True, True]
# planning done!:  9
# [True, True, True, True, True, True, True]
# planning done!:  9
# [True, True, True, True, True, True, True]
# planning done!:  9
# [True, True, True, True, True, True, True]
# planning done!:  9
# [True, True, True, True, True, True, True]
# planning done!:  9
# [True, True, True, True, True, True, True]
# planning done!:  9
# [True, True, True, True, True, True, True]
# planning done!:  10
# [True, True, True, True, True, True]
# planning done!:  10
# [True, True, True, True, True, True]
# planning done!:  10
# [True, True, True, True, True, True]
# planning done!:  10
# [True, True, True, True, True, True]
# planning done!:  10
# [True, True, True, True, True, True]
# planning done!:  10
# [True, True, True, True, True, True]
# planning done!:  10
# [True, True, True, True, True, True]
# planning done!:  11
# [True, True, True, True, True, True]
# planning done!:  11
# [True, True, True, True, True, True]
# planning done!:  11
# [True, True, True, True, True, True]
# planning done!:  11
# [True, True, True, True, True, True]
# planning done!:  11
# [True, True, True, True, True, True]
# planning done!:  11
# [True, True, True, True, True, True]
# planning done!:  12
# [True, True, True, True, True, True]
# planning done!:  12
# [True, True, True, True, True, True]
# planning done!:  12
# [True, True, True, True, True, True]
# planning done!:  12
# [True, True, True, True, True, True]
# planning done!:  12
# [True, True, True, True, True, True]
# planning done!:  12
# [True, True, True, True, True, True]
# planning done!:  13
# [True, True, True, True, True, True]
# planning done!:  13
# [True, True, True, True, True, True]
# planning done!:  13
# [True, True, True, True, True, True]
# planning done!:  13
# [True, True, True, True, True, True]
# planning done!:  13
# [True, True, True, True, True, True]
# planning done!:  13
# [True, True, True, True, True, True]
# planning done!:  14
# [True, True, True, True, True, True]
# planning done!:  14
# [True, True, True, True, True, True]
# planning done!:  14
# [True, True, True, True, True, True]
# planning done!:  14
# [True, True, True, True, True, True]
# planning done!:  14
# [True, True, True, True, True, True]
# planning done!:  14
# [True, True, True, True, True, True]
# planning done!:  15
# [True]
# planning done!:  15
# [True]
# planning done!:  15
# [True]
# planning done!:  15
# [True]
# planning done!:  15
# [True]
# planning done!:  15
# [True]
# Saved graph: Town03_Roundabout

# %% [markdown]
# [scenario] [Town05] [Highway1]

# %%
from pathlib import Path
import sys
# add <project>/src to sys.path
sys.path.insert(0, str(Path.cwd().resolve().parents[1]))
# now imports work
from motion_planning.graph_construction.main_graph_construction import GraphConstruction

from motion_planning.utils.launch_carla import *  
from motion_planning.graph_construction.route_loading import *
from motion_planning.visualizations.graph_visualization import GRAPH_VISUALIZATION
from motion_planning.graph_construction.graph_assets import GRAPH_FILE_HANDLER
from motion_planning.utils.paths import GRAPH_DIR, ROUTES_DIR
from pathlib import Path
import time


map_id_key = 'Town05'
scenario_key = 'Highway1'


launch_carla_server()
time.sleep(5)  # wait for server to be ready
print(f"Processing map={map_id_key}, scenario={scenario_key} ...")
gc = GraphConstruction(map_id_key, scenario_key, n_seperated_wps=10, num_paths=10, path_offset=1, scenario=scenario_key)
gc.construct_graph_from_carla_route()
# build frenet and networkx structures
gc.create_frenet_graph()
G_all, goal_indices, ref = gc.create_graph_data_structure()
# save using existing handler and GRAPH_DIR
GV = GRAPH_VISUALIZATION(gc.V, gc.E, world= gc.get_current_world(), scenario=scenario_key)
GV.visualize_final_graph_matplotlib()
GV.visualize_final_graph_carla()
graph_handler = GRAPH_FILE_HANDLER()
save_name = f"{map_id_key}_{scenario_key}"
graph_handler.save_graph(graph=G_all, save_dir=GRAPH_DIR, scenario=save_name)
graph_handler.save_reference_path_csv(path=ref, save_dir=ROUTES_DIR, scenario=save_name)

print(f"Saved graph: {save_name}")
# close_carla_server()
time.sleep(5)  # ensure server is closed before next iteration
# Out:
# Processing map=Town05, scenario=Highway1 ...
# Scenario:  Highway1
# Location(x=-228.000000, y=18.500000, z=10.000000)
# Goal is: Location(x=-85.000000, y=-189.000000, z=10.000000)
# waypoints:  [-229.07347107   18.45848465] [-229.05932617   17.45858383]
# ego theta:  -1.5566509698027362
# waypoints:  [-228.90246582    3.3463335 ] [-228.9022522     2.32883406]
# ego theta:  -1.5705863777434317
# waypoints:  [-229.06089783  -11.79197979] [-229.07563782  -12.79187298]
# ego theta:  -1.5855368238893208
# waypoints:  [-229.28184509  -26.79035568] [-229.29658508  -27.79024887]
# ego theta:  -1.5855368238893208
# waypoints:  [-229.50279236  -41.78872681] [-229.51753235  -42.78862   ]
# ego theta:  -1.5855368238893208
# waypoints:  [-229.72373962  -56.78710175] [-229.73847961  -57.78699112]
# ego theta:  -1.5855368801179301
# waypoints:  [-229.94468689  -71.78546906] [-229.95942688  -72.78536224]
# ego theta:  -1.5855368238893208
# waypoints:  [-230.16563416  -86.78384399] [-230.18037415  -87.78372955]
# ego theta:  -1.5855369363469685
# waypoints:  [-230.32778931 -101.47913361] [-230.30502319 -102.39065552]
# ego theta:  -1.545825581771701
# waypoints:  [-229.0244751  -115.08084869] [-228.8646698  -115.97853851]
# ego theta:  -1.3946234687389951
# waypoints:  [-225.68733215 -128.33110046] [-225.39414978 -129.19445801]
# ego theta:  -1.243430797300252
# waypoints:  [-220.39251709 -140.92752075] [-219.97261047 -141.7368927 ]
# ego theta:  -1.0922177515364608
# waypoints:  [-213.26081848 -152.58274841] [-212.72380066 -153.31964111]
# ego theta:  -0.9410280619706569
# waypoints:  [-204.45495605 -163.03083801] [-203.81309509 -163.67842102]
# ego theta:  -0.7898357415109839
# waypoints:  [-194.1758728  -172.03337097] [-193.44380188 -172.5769043 ]
# ego theta:  -0.6386579724568049
# waypoints:  [-182.65811157 -179.38496399] [-181.85250854 -179.81204224]
# ego theta:  -0.4874638579626257
# waypoints:  [-170.16442871 -184.91790771] [-169.30368042 -185.21876526]
# ego theta:  -0.3362562504274492
# waypoints:  [-156.97990417 -188.50590515] [-156.0836792 -188.6736908]
# ego theta:  -0.1850714138392154
# waypoints:  [-143.40536499 -190.06712341] [-142.49409485 -190.09799194]
# ego theta:  -0.03386123409920191
# waypoints:  [-128.75839233 -190.12081909] [-127.75839996 -190.11947632]
# ego theta:  0.0013427828750839173
# Warning: No valid nodes found in layer  1
# Warning: No valid nodes found in layer  7
# ego theta:  0.0013427828750839173
# V[-1]= [<motion_planning.graph_construction.graph_assets.Node object at 0x724e26590c10>, <motion_planning.graph_construction.graph_assets.Node object at 0x724e26590af0>, <motion_planning.graph_construction.graph_assets.Node object at 0x724e26590ac0>]
# last layer:  [-85.75843811035156, -190.0634765625, 0.0013427828750839173, None]
# layer  0  has  1  nodes
# layer  1  has  3  nodes
# layer  2  has  3  nodes
# layer  3  has  3  nodes
# layer  4  has  3  nodes
# layer  5  has  3  nodes
# layer  6  has  3  nodes
# layer  7  has  3  nodes
# layer  8  has  3  nodes
# layer  9  has  3  nodes
# layer  10  has  3  nodes
# layer  11  has  3  nodes
# layer  12  has  3  nodes
# layer  13  has  3  nodes
# layer  14  has  3  nodes
# layer  15  has  3  nodes
# layer  16  has  3  nodes
# layer  17  has  3  nodes
# layer  18  has  3  nodes
# layer  19  has  1  nodes
# planning done!:  0
# [True, True, True]
# planning done!:  1
# [True, True, True]
# planning done!:  1
# [True, True, True]
# planning done!:  1
# [True, True, True]
# planning done!:  2
# [True, True, True]
# planning done!:  2
# [True, True, True]
# planning done!:  2
# [True, True, True]
# planning done!:  3
# [True, True, True]
# planning done!:  3
# [True, True, True]
# planning done!:  3
# [True, True, True]
# planning done!:  4
# [True, True, True]
# planning done!:  4
# [True, True, True]
# planning done!:  4
# [True, True, True]
# planning done!:  5
# [True, True, True]
# planning done!:  5
# [True, True, True]
# planning done!:  5
# [True, True, True]
# planning done!:  6
# [True, True, True]
# planning done!:  6
# [True, True, True]
# planning done!:  6
# [True, True, True]
# planning done!:  7
# [True, True, True]
# planning done!:  7
# [True, True, True]
# planning done!:  7
# [True, True, True]
# planning done!:  8
# [True, True, True]
# planning done!:  8
# [True, True, True]
# planning done!:  8
# [True, True, True]
# /home/abdulrahman/competitive-online-algorithms-motion-planning/src/motion_planning/graph_construction/path_optimization.py:87: RuntimeWarning: Method L-BFGS-B cannot handle constraints.
#   res = scipy.optimize.minimize(self.objective, p0, method='L-BFGS-B', jac=self.objective_grad, constraints=bounds)
# planning done!:  9
# [True, True, True]
# planning done!:  9
# [True, True, True]
# planning done!:  9
# [True, True, True]
# planning done!:  10
# [True, True, True]
# planning done!:  10
# [True, True, True]
# planning done!:  10
# [True, True, True]
# planning done!:  11
# [True, True, True]
# planning done!:  11
# [True, True, True]
# planning done!:  11
# [True, True, True]
# planning done!:  12
# [True, True, True]
# planning done!:  12
# [True, True, True]
# planning done!:  12
# [True, True, True]
# planning done!:  13
# [True, True, True]
# planning done!:  13
# [True, True, True]
# planning done!:  13
# [True, True, True]
# planning done!:  14
# [True, True, True]
# planning done!:  14
# [True, True, True]
# planning done!:  14
# [True, True, True]
# planning done!:  15
# [True, True, True]
# planning done!:  15
# [True, True, True]
# planning done!:  15
# [True, True, True]
# planning done!:  16
# [True, True, True]
# planning done!:  16
# [True, True, True]
# planning done!:  16
# [True, True, True]
# planning done!:  17
# [True, True, True]
# planning done!:  17
# [True, True, True]
# planning done!:  17
# [True, True, True]
# planning done!:  18
# [True]
# planning done!:  18
# [True]
# planning done!:  18
# [True]
# Saved graph: Town05_Highway1

# %%
GV.visualize_final_graph_carla()

# %% [markdown]
# [scenario] [Town05] [Highway2]

# %%
from pathlib import Path
import sys
# add <project>/src to sys.path
sys.path.insert(0, str(Path.cwd().resolve().parents[1]))
# now imports work
from motion_planning.graph_construction.main_graph_construction import GraphConstruction

from motion_planning.utils.launch_carla import *  
from motion_planning.graph_construction.route_loading import *
from motion_planning.visualizations.graph_visualization import GRAPH_VISUALIZATION
from motion_planning.graph_construction.graph_assets import GRAPH_FILE_HANDLER
from motion_planning.utils.paths import GRAPH_DIR, ROUTES_DIR
from pathlib import Path
import time


map_id_key = 'Town05'
scenario_key = 'Highway2'

launch_carla_server()
time.sleep(5)  # wait for server to be ready
print(f"Processing map={map_id_key}, scenario={scenario_key} ...")
gc = GraphConstruction(map_id_key, scenario_key, n_seperated_wps=10, num_paths=10, path_offset=1, scenario=scenario_key)
gc.construct_graph_from_carla_route()
# build frenet and networkx structures
gc.create_frenet_graph()
G_all, goal_indices, ref = gc.create_graph_data_structure()
# save using existing handler and GRAPH_DIR
GV = GRAPH_VISUALIZATION(gc.V, gc.E, world= gc.get_current_world(), scenario=scenario_key)
GV.visualize_final_graph_matplotlib()
GV.visualize_final_graph_carla()
graph_handler = GRAPH_FILE_HANDLER()
save_name = f"{map_id_key}_{scenario_key}"
graph_handler.save_graph(graph=G_all, save_dir=GRAPH_DIR, scenario=save_name)
graph_handler.save_reference_path_csv(path=ref, save_dir=ROUTES_DIR, scenario=save_name)

print(f"Saved graph: {save_name}")
# close_carla_server()
time.sleep(5)  # ensure server is closed before next iteration
# Out:
# Processing map=Town05, scenario=Highway2 ...
# Scenario:  Highway2
# Location(x=-228.000000, y=18.500000, z=10.000000)
# Goal is: Location(x=15.000000, y=-189.000000, z=10.000000)
# waypoints:  [-229.07347107   18.45848465] [-229.05932617   17.45858383]
# ego theta:  -1.5566509698027362
# waypoints:  [-228.90246582    3.3463335 ] [-228.9022522     2.32883406]
# ego theta:  -1.5705863777434317
# waypoints:  [-229.06089783  -11.79197979] [-229.07563782  -12.79187298]
# ego theta:  -1.5855368238893208
# waypoints:  [-229.28184509  -26.79035568] [-229.29658508  -27.79024887]
# ego theta:  -1.5855368238893208
# waypoints:  [-229.50279236  -41.78872681] [-229.51753235  -42.78862   ]
# ego theta:  -1.5855368238893208
# waypoints:  [-229.72373962  -56.78710175] [-229.73847961  -57.78699112]
# ego theta:  -1.5855368801179301
# waypoints:  [-229.94468689  -71.78546906] [-229.95942688  -72.78536224]
# ego theta:  -1.5855368238893208
# waypoints:  [-230.16563416  -86.78384399] [-230.18037415  -87.78372955]
# ego theta:  -1.5855369363469685
# waypoints:  [-230.32778931 -101.47913361] [-230.30502319 -102.39065552]
# ego theta:  -1.545825581771701
# waypoints:  [-229.0244751  -115.08084869] [-228.8646698  -115.97853851]
# ego theta:  -1.3946234687389951
# waypoints:  [-225.68733215 -128.33110046] [-225.39414978 -129.19445801]
# ego theta:  -1.243430797300252
# waypoints:  [-220.39251709 -140.92752075] [-219.97261047 -141.7368927 ]
# ego theta:  -1.0922177515364608
# waypoints:  [-213.26081848 -152.58274841] [-212.72380066 -153.31964111]
# ego theta:  -0.9410280619706569
# waypoints:  [-204.45495605 -163.03083801] [-203.81309509 -163.67842102]
# ego theta:  -0.7898357415109839
# waypoints:  [-194.1758728  -172.03337097] [-193.44380188 -172.5769043 ]
# ego theta:  -0.6386579724568049
# waypoints:  [-182.65811157 -179.38496399] [-181.85250854 -179.81204224]
# ego theta:  -0.4874638579626257
# waypoints:  [-170.16442871 -184.91790771] [-169.30368042 -185.21876526]
# ego theta:  -0.3362562504274492
# waypoints:  [-156.97990417 -188.50590515] [-156.0836792 -188.6736908]
# ego theta:  -0.1850714138392154
# waypoints:  [-143.40536499 -190.06712341] [-142.49409485 -190.09799194]
# ego theta:  -0.03386123409920191
# waypoints:  [-128.75839233 -190.12081909] [-127.75839996 -190.11947632]
# ego theta:  0.0013427828750839173
# waypoints:  [-113.75841522 -190.10079956] [-112.75841522 -190.0994873 ]
# ego theta:  0.001312255106134161
# waypoints:  [ -98.75842285 -190.08081055] [ -97.75842285 -190.07946777]
# ego theta:  0.0013427726304759077
# waypoints:  [ -83.75843811 -190.06079102] [ -82.75843811 -190.05944824]
# ego theta:  0.0013427726304759077
# waypoints:  [ -68.75845337 -190.04077148] [ -67.75845337 -190.03945923]
# ego theta:  0.001312255106134161
# waypoints:  [ -53.758461   -190.02078247] [ -52.758461  -190.0194397]
# ego theta:  0.0013427726304759077
# waypoints:  [ -38.75847626 -190.00076294] [ -37.75847626 -189.99942017]
# ego theta:  0.0013427726304759077
# waypoints:  [ -23.75848961 -189.98074341] [ -22.75849152 -189.97943115]
# ego theta:  0.0013122576090640443
# Warning: No valid nodes found in layer  1
# Warning: No valid nodes found in layer  7
# ego theta:  0.0013122576090640443
# V[-1]= [<motion_planning.graph_construction.graph_assets.Node object at 0x776d54789600>, <motion_planning.graph_construction.graph_assets.Node object at 0x776d547895d0>, <motion_planning.graph_construction.graph_assets.Node object at 0x776d547895a0>]
# last layer:  [19.340087890625, -190.03488159179688, 0.0013122576090640443, None]
# layer  0  has  1  nodes
# layer  1  has  3  nodes
# layer  2  has  3  nodes
# layer  3  has  3  nodes
# layer  4  has  3  nodes
# layer  5  has  3  nodes
# layer  6  has  3  nodes
# layer  7  has  3  nodes
# layer  8  has  3  nodes
# layer  9  has  3  nodes
# layer  10  has  3  nodes
# layer  11  has  3  nodes
# layer  12  has  3  nodes
# layer  13  has  3  nodes
# layer  14  has  3  nodes
# layer  15  has  3  nodes
# layer  16  has  3  nodes
# layer  17  has  3  nodes
# layer  18  has  3  nodes
# layer  19  has  3  nodes
# layer  20  has  3  nodes
# layer  21  has  3  nodes
# layer  22  has  3  nodes
# layer  23  has  3  nodes
# layer  24  has  3  nodes
# layer  25  has  3  nodes
# layer  26  has  1  nodes
# planning done!:  0
# [True, True, True]
# planning done!:  1
# [True, True, True]
# planning done!:  1
# [True, True, True]
# planning done!:  1
# [True, True, True]
# planning done!:  2
# [True, True, True]
# planning done!:  2
# [True, True, True]
# /home/abdulrahman/competitive-online-algorithms-motion-planning/src/motion_planning/graph_construction/path_optimization.py:87: RuntimeWarning: Method L-BFGS-B cannot handle constraints.
#   res = scipy.optimize.minimize(self.objective, p0, method='L-BFGS-B', jac=self.objective_grad, constraints=bounds)
# planning done!:  2
# [True, True, True]
# planning done!:  3
# [True, True, True]
# planning done!:  3
# [True, True, True]
# planning done!:  3
# [True, True, True]
# planning done!:  4
# [True, True, True]
# planning done!:  4
# [True, True, True]
# planning done!:  4
# [True, True, True]
# planning done!:  5
# [True, True, True]
# planning done!:  5
# [True, True, True]
# planning done!:  5
# [True, True, True]
# planning done!:  6
# [True, True, True]
# planning done!:  6
# [True, True, True]
# planning done!:  6
# [True, True, True]
# planning done!:  7
# [True, True, True]
# planning done!:  7
# [True, True, True]
# planning done!:  7
# [True, True, True]
# planning done!:  8
# [True, True, True]
# planning done!:  8
# [True, True, True]
# planning done!:  8
# [True, True, True]
# planning done!:  9
# [True, True, True]
# planning done!:  9
# [True, True, True]
# planning done!:  9
# [True, True, True]
# planning done!:  10
# [True, True, True]
# planning done!:  10
# [True, True, True]
# planning done!:  10
# [True, True, True]
# planning done!:  11
# [True, True, True]
# planning done!:  11
# [True, True, True]
# planning done!:  11
# [True, True, True]
# planning done!:  12
# [True, True, True]
# planning done!:  12
# [True, True, True]
# planning done!:  12
# [True, True, True]
# planning done!:  13
# [True, True, True]
# planning done!:  13
# [True, True, True]
# planning done!:  13
# [True, True, True]
# planning done!:  14
# [True, True, True]
# planning done!:  14
# [True, True, True]
# planning done!:  14
# [True, True, True]
# planning done!:  15
# [True, True, True]
# planning done!:  15
# [True, True, True]
# planning done!:  15
# [True, True, True]
# planning done!:  16
# [True, True, True]
# planning done!:  16
# [True, True, True]
# planning done!:  16
# [True, True, True]
# planning done!:  17
# [True, True, True]
# planning done!:  17
# [True, True, True]
# planning done!:  17
# [True, True, True]
# planning done!:  18
# [True, True, True]
# planning done!:  18
# [True, True, True]
# planning done!:  18
# [True, True, True]
# planning done!:  19
# [True, True, True]
# planning done!:  19
# [True, True, True]
# planning done!:  19
# [True, True, True]
# planning done!:  20
# [True, True, True]
# planning done!:  20
# [True, True, True]
# planning done!:  20
# [True, True, True]
# planning done!:  21
# [True, True, True]
# planning done!:  21
# [True, True, True]
# planning done!:  21
# [True, True, True]
# planning done!:  22
# [True, True, True]
# planning done!:  22
# [True, True, True]
# planning done!:  22
# [True, True, True]
# planning done!:  23
# [True, True, True]
# planning done!:  23
# [True, True, True]
# planning done!:  23
# [True, True, True]
# planning done!:  24
# [True, True, True]
# planning done!:  24
# [True, True, True]
# planning done!:  24
# [True, True, True]
# planning done!:  25
# [True]
# planning done!:  25
# [True]
# planning done!:  25
# [True]
# Saved graph: Town05_Highway2

# %% [markdown]
# [scenario] [Town05] [Highway3]

# %%
from pathlib import Path
import sys
# add <project>/src to sys.path
sys.path.insert(0, str(Path.cwd().resolve().parents[1]))
# now imports work
from motion_planning.graph_construction.main_graph_construction import GraphConstruction

from motion_planning.utils.launch_carla import *  
from motion_planning.graph_construction.route_loading import *
from motion_planning.visualizations.graph_visualization import GRAPH_VISUALIZATION
from motion_planning.graph_construction.graph_assets import GRAPH_FILE_HANDLER
from motion_planning.utils.paths import GRAPH_DIR, ROUTES_DIR
from pathlib import Path
import time


map_id_key = 'Town05'
scenario_key = 'Highway3'

launch_carla_server()
time.sleep(5)  # wait for server to be ready
print(f"Processing map={map_id_key}, scenario={scenario_key} ...")
gc = GraphConstruction(map_id_key, scenario_key, n_seperated_wps=10, num_paths=10, path_offset=1, scenario=scenario_key)
gc.construct_graph_from_carla_route()
# build frenet and networkx structures
gc.create_frenet_graph()
G_all, goal_indices, ref = gc.create_graph_data_structure()
# save using existing handler and GRAPH_DIR
GV = GRAPH_VISUALIZATION(gc.V, gc.E, world= gc.get_current_world(), scenario=scenario_key)
GV.visualize_final_graph_matplotlib()
GV.visualize_final_graph_carla()
graph_handler = GRAPH_FILE_HANDLER()
save_name = f"{map_id_key}_{scenario_key}"
graph_handler.save_graph(graph=G_all, save_dir=GRAPH_DIR, scenario=save_name)
graph_handler.save_reference_path_csv(path=ref, save_dir=ROUTES_DIR, scenario=save_name)

print(f"Saved graph: {save_name}")
# close_carla_server()
time.sleep(5)  # ensure server is closed before next iteration
# Out:
# Processing map=Town05, scenario=Highway3 ...
# Scenario:  Highway3
# Location(x=-228.000000, y=18.500000, z=10.000000)
# Goal is: Location(x=107.000000, y=-189.000000, z=10.000000)
# waypoints:  [-229.07347107   18.45848465] [-229.05932617   17.45858383]
# ego theta:  -1.5566509698027362
# waypoints:  [-228.90246582    3.3463335 ] [-228.9022522     2.32883406]
# ego theta:  -1.5705863777434317
# waypoints:  [-229.06089783  -11.79197979] [-229.07563782  -12.79187298]
# ego theta:  -1.5855368238893208
# waypoints:  [-229.28184509  -26.79035568] [-229.29658508  -27.79024887]
# ego theta:  -1.5855368238893208
# waypoints:  [-229.50279236  -41.78872681] [-229.51753235  -42.78862   ]
# ego theta:  -1.5855368238893208
# waypoints:  [-229.72373962  -56.78710175] [-229.73847961  -57.78699112]
# ego theta:  -1.5855368801179301
# waypoints:  [-229.94468689  -71.78546906] [-229.95942688  -72.78536224]
# ego theta:  -1.5855368238893208
# waypoints:  [-230.16563416  -86.78384399] [-230.18037415  -87.78372955]
# ego theta:  -1.5855369363469685
# waypoints:  [-230.32778931 -101.47913361] [-230.30502319 -102.39065552]
# ego theta:  -1.545825581771701
# waypoints:  [-229.0244751  -115.08084869] [-228.8646698  -115.97853851]
# ego theta:  -1.3946234687389951
# waypoints:  [-225.68733215 -128.33110046] [-225.39414978 -129.19445801]
# ego theta:  -1.243430797300252
# waypoints:  [-220.39251709 -140.92752075] [-219.97261047 -141.7368927 ]
# ego theta:  -1.0922177515364608
# waypoints:  [-213.26081848 -152.58274841] [-212.72380066 -153.31964111]
# ego theta:  -0.9410280619706569
# waypoints:  [-204.45495605 -163.03083801] [-203.81309509 -163.67842102]
# ego theta:  -0.7898357415109839
# waypoints:  [-194.1758728  -172.03337097] [-193.44380188 -172.5769043 ]
# ego theta:  -0.6386579724568049
# waypoints:  [-182.65811157 -179.38496399] [-181.85250854 -179.81204224]
# ego theta:  -0.4874638579626257
# waypoints:  [-170.16442871 -184.91790771] [-169.30368042 -185.21876526]
# ego theta:  -0.3362562504274492
# waypoints:  [-156.97990417 -188.50590515] [-156.0836792 -188.6736908]
# ego theta:  -0.1850714138392154
# waypoints:  [-143.40536499 -190.06712341] [-142.49409485 -190.09799194]
# ego theta:  -0.03386123409920191
# waypoints:  [-128.75839233 -190.12081909] [-127.75839996 -190.11947632]
# ego theta:  0.0013427828750839173
# waypoints:  [-113.75841522 -190.10079956] [-112.75841522 -190.0994873 ]
# ego theta:  0.001312255106134161
# waypoints:  [ -98.75842285 -190.08081055] [ -97.75842285 -190.07946777]
# ego theta:  0.0013427726304759077
# waypoints:  [ -83.75843811 -190.06079102] [ -82.75843811 -190.05944824]
# ego theta:  0.0013427726304759077
# waypoints:  [ -68.75845337 -190.04077148] [ -67.75845337 -190.03945923]
# ego theta:  0.001312255106134161
# waypoints:  [ -53.758461   -190.02078247] [ -52.758461  -190.0194397]
# ego theta:  0.0013427726304759077
# waypoints:  [ -38.75847626 -190.00076294] [ -37.75847626 -189.99942017]
# ego theta:  0.0013427726304759077
# waypoints:  [ -23.75848961 -189.98074341] [ -22.75849152 -189.97943115]
# ego theta:  0.0013122576090640443
# waypoints:  [  -8.75850296 -189.96075439] [  -7.75850439 -189.95941162]
# ego theta:  0.0013427745513280023
# waypoints:  [   7.13019705 -189.98310852] [   8.13018799 -189.98735046]
# ego theta:  -0.004241956347620174
# waypoints:  [  22.34006119 -190.04759216] [  23.34005165 -190.05183411]
# ego theta:  -0.004241958370337609
# waypoints:  [  37.33992386 -190.1111908 ] [  38.33991623 -190.11543274]
# ego theta:  -0.004241950279479442
# waypoints:  [  52.34978867 -190.17481995] [  53.34978104 -190.17906189]
# ego theta:  -0.004241950279479442
# waypoints:  [  67.34964752 -190.23841858] [  68.34963989 -190.24266052]
# ego theta:  -0.004241950279479442
# waypoints:  [  82.41951752 -190.30230713] [  83.41950989 -190.30654907]
# ego theta:  -0.004241950279479442
# waypoints:  [  97.41938782 -190.36590576] [  98.41937256 -190.37014771]
# ego theta:  -0.004241982643097297
# waypoints:  [ 111.27865601 -189.68049622] [ 112.18457031 -189.56407166]
# ego theta:  0.127815475149245
# waypoints:  [ 124.70139313 -186.99964905] [ 125.58010101 -186.75042725]
# ego theta:  0.27636517687916196
# waypoints:  [ 137.57965088 -182.36204529] [ 138.4118042  -181.98554993]
# ego theta:  0.4248771015599473
# waypoints:  [ 149.62986755 -175.86979675] [ 150.39715576 -175.37431335]
# ego theta:  0.5733881917479571
# waypoints:  [ 160.58670044 -167.66586304] [ 161.2722168  -167.06230164]
# ego theta:  0.7219071886207732
# waypoints:  [ 170.20890808 -157.93089294] [ 170.7975769  -157.23252869]
# ego theta:  0.8704239217707226
# waypoints:  [ 178.28463745 -146.87922668] [ 178.76347351 -146.10144043]
# ego theta:  1.0189563814197247
# waypoints:  [ 184.63604736 -134.75418091] [ 184.99450684 -133.91410828]
# ego theta:  1.1674861616592425
# waypoints:  [ 189.12330627 -121.82277679] [ 189.35350037 -120.93890381]
# ego theta:  1.3160180681380693
# waypoints:  [ 191.64759827 -108.36971283] [ 191.74447632 -107.4615097 ]
# ego theta:  1.4645281414916225
# waypoints:  [192.26899719 -94.262146  ] [192.28067017 -93.26221466]
# ego theta:  1.5591230818333268
# waypoints:  [192.44416809 -79.26316833] [192.45584106 -78.263237  ]
# ego theta:  1.5591230818333268
# waypoints:  [192.61932373 -64.26419067] [192.63101196 -63.26425934]
# ego theta:  1.559107824078455
# waypoints:  [192.79449463 -49.26521301] [192.8061676  -48.26528168]
# ego theta:  1.5591230818333268
# Warning: No valid nodes found in layer  1
# Warning: No valid nodes found in layer  7
# ego theta:  1.5591230818333268
# V[-1]= [<motion_planning.graph_construction.graph_assets.Node object at 0x753cbe765d50>, <motion_planning.graph_construction.graph_assets.Node object at 0x753cbe765d80>, <motion_planning.graph_construction.graph_assets.Node object at 0x753cbe765db0>]
# last layer:  [193.24058532714844, -11.067806243896484, 1.5591230818333268, None]
# layer  0  has  1  nodes
# layer  1  has  3  nodes
# layer  2  has  3  nodes
# layer  3  has  3  nodes
# layer  4  has  3  nodes
# layer  5  has  3  nodes
# layer  6  has  3  nodes
# layer  7  has  3  nodes
# layer  8  has  3  nodes
# layer  9  has  3  nodes
# layer  10  has  3  nodes
# layer  11  has  3  nodes
# layer  12  has  3  nodes
# layer  13  has  3  nodes
# layer  14  has  3  nodes
# layer  15  has  3  nodes
# layer  16  has  3  nodes
# layer  17  has  3  nodes
# layer  18  has  3  nodes
# layer  19  has  3  nodes
# layer  20  has  3  nodes
# layer  21  has  3  nodes
# layer  22  has  3  nodes
# layer  23  has  3  nodes
# layer  24  has  3  nodes
# layer  25  has  3  nodes
# layer  26  has  3  nodes
# layer  27  has  3  nodes
# layer  28  has  3  nodes
# layer  29  has  3  nodes
# layer  30  has  3  nodes
# layer  31  has  3  nodes
# layer  32  has  3  nodes
# layer  33  has  3  nodes
# layer  34  has  3  nodes
# layer  35  has  3  nodes
# layer  36  has  3  nodes
# layer  37  has  3  nodes
# layer  38  has  3  nodes
# layer  39  has  3  nodes
# layer  40  has  3  nodes
# layer  41  has  3  nodes
# layer  42  has  3  nodes
# layer  43  has  3  nodes
# layer  44  has  3  nodes
# layer  45  has  3  nodes
# layer  46  has  3  nodes
# layer  47  has  3  nodes
# layer  48  has  1  nodes
# planning done!:  0
# [True, True, True]
# planning done!:  1
# [True, True, True]
# /home/abdulrahman/competitive-online-algorithms-motion-planning/src/motion_planning/graph_construction/path_optimization.py:87: RuntimeWarning: Method L-BFGS-B cannot handle constraints.
#   res = scipy.optimize.minimize(self.objective, p0, method='L-BFGS-B', jac=self.objective_grad, constraints=bounds)
# planning done!:  1
# [True, True, True]
# planning done!:  1
# [True, True, True]
# planning done!:  2
# [True, True, True]
# planning done!:  2
# [True, True, True]
# planning done!:  2
# [True, True, True]
# planning done!:  3
# [True, True, True]
# planning done!:  3
# [True, True, True]
# planning done!:  3
# [True, True, True]
# planning done!:  4
# [True, True, True]
# planning done!:  4
# [True, True, True]
# planning done!:  4
# [True, True, True]
# planning done!:  5
# [True, True, True]
# planning done!:  5
# [True, True, True]
# planning done!:  5
# [True, True, True]
# planning done!:  6
# [True, True, True]
# planning done!:  6
# [True, True, True]
# planning done!:  6
# [True, True, True]
# planning done!:  7
# [True, True, True]
# planning done!:  7
# [True, True, True]
# planning done!:  7
# [True, True, True]
# planning done!:  8
# [True, True, True]
# planning done!:  8
# [True, True, True]
# planning done!:  8
# [True, True, True]
# planning done!:  9
# [True, True, True]
# planning done!:  9
# [True, True, True]
# planning done!:  9
# [True, True, True]
# planning done!:  10
# [True, True, True]
# planning done!:  10
# [True, True, True]
# planning done!:  10
# [True, True, True]
# planning done!:  11
# [True, True, True]
# planning done!:  11
# [True, True, True]
# planning done!:  11
# [True, True, True]
# planning done!:  12
# [True, True, True]
# planning done!:  12
# [True, True, True]
# planning done!:  12
# [True, True, True]
# planning done!:  13
# [True, True, True]
# planning done!:  13
# [True, True, True]
# planning done!:  13
# [True, True, True]
# planning done!:  14
# [True, True, True]
# planning done!:  14
# [True, True, True]
# planning done!:  14
# [True, True, True]
# planning done!:  15
# [True, True, True]
# planning done!:  15
# [True, True, True]
# planning done!:  15
# [True, True, True]
# planning done!:  16
# [True, True, True]
# planning done!:  16
# [True, True, True]
# planning done!:  16
# [True, True, True]
# planning done!:  17
# [True, True, True]
# planning done!:  17
# [True, True, True]
# planning done!:  17
# [True, True, True]
# planning done!:  18
# [True, True, True]
# planning done!:  18
# [True, True, True]
# planning done!:  18
# [True, True, True]
# planning done!:  19
# [True, True, True]
# planning done!:  19
# [True, True, True]
# planning done!:  19
# [True, True, True]
# planning done!:  20
# [True, True, True]
# planning done!:  20
# [True, True, True]
# planning done!:  20
# [True, True, True]
# planning done!:  21
# [True, True, True]
# planning done!:  21
# [True, True, True]
# planning done!:  21
# [True, True, True]
# planning done!:  22
# [True, True, True]
# planning done!:  22
# [True, True, True]
# planning done!:  22
# [True, True, True]
# planning done!:  23
# [True, True, True]
# planning done!:  23
# [True, True, True]
# planning done!:  23
# [True, True, True]
# planning done!:  24
# [True, True, True]
# planning done!:  24
# [True, True, True]
# planning done!:  24
# [True, True, True]
# planning done!:  25
# [True, True, True]
# planning done!:  25
# [True, True, True]
# planning done!:  25
# [True, True, True]
# planning done!:  26
# [True, True, True]
# planning done!:  26
# [True, True, True]
# planning done!:  26
# [True, True, True]
# planning done!:  27
# [True, True, True]
# planning done!:  27
# [True, True, True]
# planning done!:  27
# [True, True, True]
# planning done!:  28
# [True, True, True]
# planning done!:  28
# [True, True, True]
# planning done!:  28
# [True, True, True]
# planning done!:  29
# [True, True, True]
# planning done!:  29
# [True, True, True]
# planning done!:  29
# [True, True, True]
# planning done!:  30
# [True, True, True]
# planning done!:  30
# [True, True, True]
# planning done!:  30
# [True, True, True]
# planning done!:  31
# [True, True, True]
# planning done!:  31
# [True, True, True]
# planning done!:  31
# [True, True, True]
# planning done!:  32
# [True, True, True]
# planning done!:  32
# [True, True, True]
# planning done!:  32
# [True, True, True]
# planning done!:  33
# [True, True, True]
# planning done!:  33
# [True, True, True]
# planning done!:  33
# [True, True, True]
# planning done!:  34
# [True, True, True]
# planning done!:  34
# [True, True, True]
# planning done!:  34
# [True, True, True]
# planning done!:  35
# [True, True, True]
# planning done!:  35
# [True, True, True]
# planning done!:  35
# [True, True, True]
# planning done!:  36
# [True, True, True]
# planning done!:  36
# [True, True, True]
# planning done!:  36
# [True, True, True]
# planning done!:  37
# [True, True, True]
# planning done!:  37
# [True, True, True]
# planning done!:  37
# [True, True, True]
# planning done!:  38
# [True, True, True]
# planning done!:  38
# [True, True, True]
# planning done!:  38
# [True, True, True]
# planning done!:  39
# [True, True, True]
# planning done!:  39
# [True, True, True]
# planning done!:  39
# [True, True, True]
# planning done!:  40
# [True, True, True]
# planning done!:  40
# [True, True, True]
# planning done!:  40
# [True, True, True]
# planning done!:  41
# [True, True, True]
# planning done!:  41
# [True, True, True]
# planning done!:  41
# [True, True, True]
# planning done!:  42
# [True, True, True]
# planning done!:  42
# [True, True, True]
# planning done!:  42
# [True, True, True]
# planning done!:  43
# [True, True, True]
# planning done!:  43
# [True, True, True]
# planning done!:  43
# [True, True, True]
# planning done!:  44
# [True, True, True]
# planning done!:  44
# [True, True, True]
# planning done!:  44
# [True, True, True]
# planning done!:  45
# [True, True, True]
# planning done!:  45
# [True, True, True]
# planning done!:  45
# [True, True, True]
# planning done!:  46
# [True, True, True]
# planning done!:  46
# [True, True, True]
# planning done!:  46
# [True, True, True]
# planning done!:  47
# [True]
# planning done!:  47
# [True]
# planning done!:  47
# [True]
# Saved graph: Town05_Highway3

# %% [markdown]
# [scenario] [Town05] [Multiple-Intersections]

# %%
import math
from pathlib import Path
import sys
sys.path.insert(0, str(Path.cwd().resolve().parents[1]))

import pandas as pd
import matplotlib.pyplot as plt
from typing import List, Dict, Optional
from motion_planning.utils.paths import ROUTES_DIR
from motion_planning.graph_construction.graph_assets import GRAPH_FILE_HANDLER
graph_handler = GRAPH_FILE_HANDLER()

def plot_reference_paths(
    scenarios: Optional[List[str]] = None,
    routes_dir: Path = ROUTES_DIR,
    handler=graph_handler,
    show: bool = True,
    slot_size=(4, 6)
) -> Dict[str, pd.DataFrame]:
    routes_dir = Path(routes_dir)
    if scenarios is None:
        csv_files = sorted(routes_dir.glob("*.csv"))
        scenarios = [p.stem for p in csv_files]

    loaded: Dict[str, pd.DataFrame] = {}
    for scen in scenarios:
        csv_file = routes_dir / f"{scen}.csv"
        if not csv_file.exists():
            csv_file = routes_dir / f"{scen.replace(' ', '_')}.csv"
        if csv_file.exists():
            df = pd.read_csv(csv_file, header=None)
            if df.shape[1] >= 2:
                df = df.iloc[:, :2]
                df.columns = ["x", "y"]
                loaded[scen] = df
        else:
            print(f"Warning: reference for '{scen}' not found in {routes_dir}")

    if not loaded:
        print("No reference paths to plot.")
        return loaded

    num_plots = len(loaded)
    cols = math.ceil(math.sqrt(num_plots))
    rows = math.ceil(num_plots / cols)
    fig, axes = plt.subplots(
        rows,
        cols,
        figsize=(cols * slot_size[0], rows * slot_size[1])
    )
    if num_plots == 1:
        axes = [axes]
    else:
        axes = axes.flatten()

    for idx, (scen, df) in enumerate(loaded.items()):
        ax = axes[idx]
        ax.plot(df["x"], df["y"], label=scen)
        ax.set_aspect("equal", "box")
        ax.set_xlabel("x")
        ax.set_ylabel("y")
        ax.set_title(scen)
        ax.legend(fontsize="small", loc="best")

    # for ax in axes[num_plots:]:
    #     ax.axis("off")

    fig.tight_layout()
    if show:
        plt.show()

    return loaded

# %%
# Test the plot_reference_paths function and display the plots
loaded_refs = plot_reference_paths(show=True)
print(f"Loaded {len(loaded_refs)} reference paths: {list(loaded_refs.keys())}")
# Out:
# Loaded 6 reference paths: ['reference_path_Town01_T-Intersection', 'reference_path_Town03_Roundabout', 'reference_path_Town05_Highway1', 'reference_path_Town05_Highway2', 'reference_path_Town05_Highway3', 'reference_path_Town05_Multiple Intersections']

# %%
from pathlib import Path
import sys
# add <project>/src to sys.path
sys.path.insert(0, str(Path.cwd().resolve().parents[1]))
# now imports work
from motion_planning.graph_construction.main_graph_construction import GraphConstruction

from motion_planning.utils.launch_carla import *  
from motion_planning.graph_construction.route_loading import *
from motion_planning.visualizations.graph_visualization import GRAPH_VISUALIZATION
from motion_planning.graph_construction.graph_assets import GRAPH_FILE_HANDLER
from motion_planning.utils.paths import GRAPH_DIR, ROUTES_DIR
from pathlib import Path
import time


map_id_key = 'Town05'
scenario_key = 'Multiple Intersections'

launch_carla_server()
time.sleep(5)  # wait for server to be ready
print(f"Processing map={map_id_key}, scenario={scenario_key} ...")
gc = GraphConstruction(map_id_key, scenario_key, n_seperated_wps=10, num_paths=10, path_offset=1, scenario=scenario_key)
gc.construct_graph_from_carla_route()
# build frenet and networkx structures
gc.create_frenet_graph()
G_all, goal_indices, ref = gc.create_graph_data_structure()
# save using existing handler and GRAPH_DIR
GV = GRAPH_VISUALIZATION(gc.V, gc.E, world= gc.get_current_world(), scenario=scenario_key)
GV.visualize_final_graph_matplotlib()
GV.visualize_final_graph_carla()
graph_handler = GRAPH_FILE_HANDLER()
save_name = f"{map_id_key}_{scenario_key}"
graph_handler.save_graph(graph=G_all, save_dir=GRAPH_DIR, scenario=save_name)
graph_handler.save_reference_path_csv(path=ref, save_dir=ROUTES_DIR, scenario=save_name)
print(f"Saved graph: {save_name}")
# close_carla_server()
time.sleep(5)  # ensure server is closed before next iteration
# Out:
# Processing map=Town05, scenario=Multiple Intersections ...
# Scenario:  Multiple Intersections
# WARNING: Version mismatch detected: You are trying to connect to a simulator that might be incompatible with this API
# WARNING: Client API version     = 0.9.14
# WARNING: Simulator API version  = 0.9.15
# Location(x=90.000000, y=-3.500000, z=0.300000)
# Goal is: Location(x=-160.000000, y=-3.000000, z=0.300000)
# waypoints:  [90.58796692 -5.04691982] [89.07307434 -5.0476532 ]
# ego theta:  -3.141108543031319
# waypoints:  [80.07315826 -5.08696508] [79.07316589 -5.09133291]
# ego theta:  -3.137224819673197
# waypoints:  [70.07325745 -5.1306448 ] [69.07326508 -5.13501263]
# ego theta:  -3.137224819673197
# waypoints:  [60.07334518 -5.17432451] [59.07335663 -5.17869234]
# ego theta:  -3.137224803011254
# waypoints:  [50.07344437 -5.21800375] [49.073452   -5.22237206]
# ego theta:  -3.137224342841499
# waypoints:  [39.41355133 -5.26456642] [38.40789413 -5.26840115]
# ego theta:  -3.137779519396838
# waypoints:  [29.27099228 -4.88861656] [28.28936958 -4.81108665]
# ego theta:  3.0627748998176014
# waypoints:  [19.42311287 -4.49797058] [18.42311668 -4.4955368 ]
# ego theta:  3.1391588722555106
# waypoints:  [ 9.16727829 -4.4730072 ] [ 8.16728115 -4.47057343]
# ego theta:  3.139158874576543
# waypoints:  [-0.83269197 -4.44866705] [-1.83268821 -4.4462328 ]
# ego theta:  3.1391583955644515
# waypoints:  [-10.83266354  -4.42432642] [-11.83265972  -4.42189217]
# ego theta:  3.1391583954193587
# waypoints:  [-20.83263016  -4.39998579] [-21.83263016  -4.39755201]
# ego theta:  3.139158881539613
# waypoints:  [-30.83260345  -4.37564564] [-31.83259964  -4.37321138]
# ego theta:  3.1391583954193587
# waypoints:  [-41.3925705   -4.34994221] [-42.39256668  -4.34750795]
# ego theta:  3.1391583954193587
# waypoints:  [-51.39253998  -4.32560158] [-52.39253998  -4.3231678 ]
# ego theta:  3.139158881539613
# waypoints:  [-61.76251221  -4.30036068] [-62.76250839  -4.29792643]
# ego theta:  3.1391583954193587
# waypoints:  [-71.76248169  -4.27602005] [-72.76248169  -4.27358627]
# ego theta:  3.139158881539613
# waypoints:  [-81.76245117  -4.2516799 ] [-82.76245117  -4.24924564]
# ego theta:  3.1391584047052796
# waypoints:  [-91.76242065  -4.22733927] [-92.76242065  -4.22490501]
# ego theta:  3.1391584047052796
# waypoints:  [-101.76239777   -4.20299911] [-102.76239014   -4.20056486]
# ego theta:  3.1391583861333663
# waypoints:  [-112.40236664   -4.17710066] [-113.40235901   -4.1746664 ]
# ego theta:  3.1391583861333663
# waypoints:  [-122.40233612   -4.15276003] [-123.40232849   -4.15032625]
# ego theta:  3.1391588629713376
# waypoints:  [-132.40229797   -4.12841988] [-133.40229797   -4.12598562]
# ego theta:  3.1391584047052796
# ego theta:  3.1391584047052796
# V[-1]= [<motion_planning.graph_construction.graph_assets.Node object at 0x708777bdc3a0>, <motion_planning.graph_construction.graph_assets.Node object at 0x708777bdc370>, <motion_planning.graph_construction.graph_assets.Node object at 0x708777bdc340>]
# last layer:  [-159.18222045898438, -4.063236236572266, 3.1391584047052796, None]
# layer  0  has  1  nodes
# layer  1  has  3  nodes
# layer  2  has  3  nodes
# layer  3  has  3  nodes
# layer  4  has  3  nodes
# layer  5  has  3  nodes
# layer  6  has  4  nodes
# layer  7  has  3  nodes
# layer  8  has  3  nodes
# layer  9  has  3  nodes
# layer  10  has  3  nodes
# layer  11  has  3  nodes
# layer  12  has  3  nodes
# layer  13  has  4  nodes
# layer  14  has  4  nodes
# layer  15  has  3  nodes
# layer  16  has  3  nodes
# layer  17  has  3  nodes
# layer  18  has  3  nodes
# layer  19  has  3  nodes
# layer  20  has  3  nodes
# layer  21  has  4  nodes
# layer  22  has  4  nodes
# layer  23  has  3  nodes
# layer  24  has  1  nodes
# planning done!:  0
# [True, True, True]
# planning done!:  1
# [True, True, True]
# planning done!:  1
# [True, True, True]
# planning done!:  1
# [True, True, True]
# planning done!:  2
# [True, True, True]
# planning done!:  2
# [True, True, True]
# planning done!:  2
# [True, True, True]
# planning done!:  3
# [True, True, True]
# planning done!:  3
# [True, True, True]
# planning done!:  3
# [True, True, True]
# planning done!:  4
# [True, True, True]
# planning done!:  4
# [True, True, True]
# planning done!:  4
# [True, True, True]
# planning done!:  5
# [True, True, True, True]
# planning done!:  5
# [True, True, True, True]
# planning done!:  5
# [True, True, True, True]
# planning done!:  6
# [True, True, True]
# planning done!:  6
# [True, True, True]
# planning done!:  6
# [True, True, True]
# planning done!:  6
# [True, True, True]
# planning done!:  7
# [True, True, True]
# planning done!:  7
# [True, True, True]
# planning done!:  7
# [True, True, True]
# planning done!:  8
# [True, True, True]
# planning done!:  8
# [True, True, True]
# planning done!:  8
# [True, True, True]
# planning done!:  9
# [True, True, True]
# planning done!:  9
# [True, True, True]
# planning done!:  9
# [True, True, True]
# planning done!:  10
# [True, True, True]
# planning done!:  10
# [True, True, True]
# planning done!:  10
# [True, True, True]
# planning done!:  11
# [True, True, True]
# planning done!:  11
# [True, True, True]
# planning done!:  11
# [True, True, True]
# planning done!:  12
# [True, True, True, True]
# /home/abdulrahman/competitive-online-algorithms-motion-planning/src/motion_planning/graph_construction/path_optimization.py:87: RuntimeWarning: Method L-BFGS-B cannot handle constraints.
#   res = scipy.optimize.minimize(self.objective, p0, method='L-BFGS-B', jac=self.objective_grad, constraints=bounds)
# planning done!:  12
# [True, True, True, True]
# planning done!:  12
# [True, True, True, True]
# planning done!:  13
# [True, True, True, True]
# planning done!:  13
# [True, True, True, True]
# planning done!:  13
# [True, True, True, True]
# planning done!:  13
# [True, True, True, True]
# planning done!:  14
# [True, True, True]
# planning done!:  14
# [True, True, True]
# planning done!:  14
# [True, True, True]
# planning done!:  14
# [True, True, True]
# planning done!:  15
# [True, True, True]
# planning done!:  15
# [True, True, True]
# planning done!:  15
# [True, True, True]
# planning done!:  16
# [True, True, True]
# planning done!:  16
# [True, True, True]
# planning done!:  16
# [True, True, True]
# planning done!:  17
# [True, True, True]
# planning done!:  17
# [True, True, True]
# planning done!:  17
# [True, True, True]
# planning done!:  18
# [True, True, True]
# planning done!:  18
# [True, True, True]
# planning done!:  18
# [True, True, True]
# planning done!:  19
# [True, True, True]
# planning done!:  19
# [True, True, True]
# planning done!:  19
# [True, True, True]
# planning done!:  20
# [True, True, True, True]
# planning done!:  20
# [True, True, True, True]
# planning done!:  20
# [True, True, True, True]
# planning done!:  21
# [True, True, True, True]
# planning done!:  21
# [True, True, True, True]
# planning done!:  21
# [True, True, True, True]
# planning done!:  21
# [True, True, True, True]
# planning done!:  22
# [True, True, True]
# planning done!:  22
# [True, True, True]
# planning done!:  22
# [True, True, True]
# planning done!:  22
# [True, True, True]
# planning done!:  23
# [True]
# planning done!:  23
# [True]
# planning done!:  23
# [True]
# Saved graph: Town05_Multiple Intersections

# %% [markdown]
# #### Loading previously saved graphs
#
# If the generation pipeline already produced and saved a scenario graph, reload it directly with
# `GRAPH_FILE_HANDLER.load_graph` to avoid reconstructing it from CARLA.

# %%
from motion_planning.graph_construction.graph_assets import GRAPH_FILE_HANDLER
from motion_planning.utils.paths import GRAPH_DIR, ROUTES_DIR

scenario_to_load = "Town05_Multiple Intersections"  # e.g., f"{map_id_key}_{scenario_key}"

handler = GRAPH_FILE_HANDLER()
loaded_graph = handler.load_graph(GRAPH_DIR, scenario_to_load)
reference_path = handler.load_reference_path_csv(ROUTES_DIR, scenario_to_load)

print(f"Loaded graph '{scenario_to_load}' with {loaded_graph.number_of_nodes()} nodes and {loaded_graph.number_of_edges()} edges")
print(f"Reference path waypoints: {len(reference_path)}")
